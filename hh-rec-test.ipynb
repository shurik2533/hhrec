# %%
from scipy import spatial
from sklearn.preprocessing import normalize

a1 = [1, 1, 1, 1]
a2 = [2, 54, 13, 15]
a3 = [2, 2, 4, 3]
print 1 - spatial.distance.cosine(a1, a2)
print 1 - spatial.distance.cosine(a1, a3)
# Out:
# 0.729580198569
# 0.957427107756

# %%
import httplib
import json
headers = {"Authorization": "Bearer PHUAM0L3PU56VNT041CJM3MUTGSABUCDTMBVHEAMF5CGCDEEIC7VFFT4VLOP0GQP", 
           "User-Agent": "hh-recommender"}
conn = httplib.HTTPSConnection("api.hh.ru")
conn.request("GET", "/resumes/mine", headers=headers)
r1 = conn.getresponse()
print r1.status, r1.reason
data = r1.read()
for i in range(len(json.loads(data)['items'])):
    resume_id = json.loads(data)['items'][i]['id']
    conn.request("GET", "/resumes/{0}".format(resume_id), headers=headers)
    r2 = conn.getresponse()
    print r2.status, r2.reason
    resume_data = r2.read()
    features = [1,2,3]
    print json.loads(resume_data)['area'] #по этому отсекаем сразу
    print json.loads(resume_data)['relocation']['area'] #этот туда же
    
    
    print [d['id'] for d in json.loads(resume_data)['specialization']] #для этого надо взять список всех специализаций. потом взять специализации по всем резюме и на их основе составить веса
    print json.loads(resume_data)['salary']
    print json.loads(resume_data)['employment']
    print json.loads(resume_data)['schedules']
    print json.loads(resume_data)['total_experience']
    print json.loads(resume_data)['skill_set']
    print json.loads(resume_data)['title'] #из этого достаем слова
    print json.loads(resume_data)['skills']
    
    print features
# Out:
# 200 OK
# 200 OK
# {u'url': u'https://api.hh.ru/areas/1', u'id': u'1', u'name': u'\u041c\u043e\u0441\u043a\u0432\u0430'}
# []
# [u'1.221', u'1.295', u'1.89']
# {u'currency': u'RUR', u'amount': 135000}
# {u'id': u'full', u'name': u'\u041f\u043e\u043b\u043d\u0430\u044f \u0437\u0430\u043d\u044f\u0442\u043e\u0441\u0442\u044c'}
# [{u'id': u'fullDay', u'name': u'\u041f\u043e\u043b\u043d\u044b\u0439 \u0434\u0435\u043d\u044c'}, {u'id': u'remote', u'name': u'\u0423\u0434\u0430\u043b\u0435\u043d\u043d\u0430\u044f \u0440\u0430\u0431\u043e\u0442\u0430'}]
# {u'months': 116}
# Java Developer
# Опытный разработчик программного обеспечения. Имею широкий спектр навыков, знаний и технологий. Разрабатываю быстрые программы, работающие с большими объемами данных в многопотоковой среде. Уделяю большое внимание качеству кода и удобству дальнейшей поддержки. Аналитически подхожу к решению задач. Имею хорошие знания алгоритмов и структур данных.
#
# Хобби, увлечения
# Интернет-технологии, путешествия, фотография, кулинария.
# Организовал и веду в местной школе кружок по программированию для детей.
# В последнее время интересуюсь машинным обучением и OpenCV
#
# Профиль на Habrahabr: http://habrahabr.ru/users/shurik2533/
# [u'Java', u'Java EE', u'Oracle Pl/SQL', u'Python', u'Data Analysis', u'Big Data', u'recommender systems', u'machine learning']
# [1, 2, 3]

# %%
import httplib
import json
import pickle
from tinydb import TinyDB
headers = {"User-Agent": "hh-recommender"}

db = TinyDB('/home/shurik2533/vacancies_test.json')
k = 0
for i in range(16823582, 0, -1): #18822744
    conn = httplib.HTTPSConnection("api.hh.ru")
    conn.request("GET", "/vacancies/{0}".format(i), headers=headers)
    r1 = conn.getresponse()
    k = k+1
    if r1.status==200:
        vacancy_data = r1.read()
        #print json.loads(vacancy_data)['archived']
        if json.loads(vacancy_data)['archived'] == False:
            db.insert(json.loads(vacancy_data))
            print json.loads(vacancy_data)['id']
            k=0
    if i%1000 == 0:
        print i
        break;
    if k == 100:
        print "break"
        break;
    
#print db.all()[0]
# Out:
# 16823578
# found
# 16823572
# found
# 16823571
# found
# 16823570
# found
# 16823568
# found
# 16823564
# found
# 16823563
# found
# 16823562
# found
# 16823561
# found
# 16823560
# found
# 16823558
# found
# 16823557
# found
# 16823556
# found
# 16823554
# found
# 16823551
# found
# 16823549
# found
# 16823547
# found
# 16823544
# found
# 16823543
# found
# 16823542
# found
# 16823540
# found
# 16823539
# found
# 16823538
# found
# 16823536
# found
# 16823534
# found
# 16823530
# found
# 16823519
# found
# 16823516
# found
# 16823506
# found
# 16823503
# found
# 16823500
# found
# 16823499
# found
# 16823498
# found
# 16823497
# found
# 16823494
# found
# 16823492
# found
# 16823491
# found
# 16823474
# found
# 16823469
# found
# 16823455
# found
# 16823450
# found
# 16823444
# found
# 16823442
# found
# 16823439
# found
# 16823416
# found
# 16823414
# found
# 16823410
# found
# 16823408
# found
# 16823407
# found
# 16823406
# found
# 16823404
# found
# 16823402
# found
# 16823401
# found
# 16823392
# found
# 16823390
# found
# 16823387
# found
# 16823384
# found
# 16823383
# found
# 16823379
# found
# 16823378
# found
# 16823377
# found
# 16823374
# found
# 16823370
# found
# 16823368
# found
# 16823366
# found
# 16823364
# found
# 16823361
# found
# 16823356
# found
# 16823355
# found
# 16823352
# found
# 16823349
# found
# 16823346
# found
# 16823344
# found
# 16823343
# found
# 16823342
# found
# 16823339
# found
# 16823338
# found
# 16823337
# found
# 16823335
# found
# 16823334
# found
# 16823333
# found
# 16823332
# found
# 16823330
# found
# 16823329
# found
# 16823328
# found
# 16823327
# found
# 16823325
# found
# 16823319
# found
# 16823315
# found
# 16823311
# found
# 16823308
# found
# 16823307
# found
# 16823306
# found
# 16823305
# found
# 16823303
# found
# 16823300
# found
# 16823299
# found
# 16823297
# found
# 16823294
# found
# 16823293
# found
# 16823278
# found
# 16823276
# found
# 16823275
# found
# 16823266
# found
# 16823264
# found
# 16823263
# found
# 16823262
# found
# 16823261
# found
# 16823259
# found
# 16823258
# found
# 16823257
# found
# 16823256
# found
# 16823255
# found
# 16823254
# found
# 16823253
# found
# 16823252
# found
# 16823250
# found
# 16823249
# found
# 16823248
# found
# 16823244
# found
# 16823240
# found
# 16823235
# found
# 16823233
# found
# 16823232
# found
# 16823231
# found
# 16823229
# found
# 16823227
# found
# 16823226
# found
# 16823225
# found
# 16823223
# found
# 16823221
# found
# 16823218
# found
# 16823216
# found
# 16823213
# found
# 16823212
# found
# 16823209
# found
# 16823208
# found
# 16823206
# found
# 16823202
# found
# 16823201
# found
# 16823199
# found
# 16823198
# found
# 16823196
# found
# 16823194
# found
# 16823192
# found
# 16823190
# found
# 16823188
# found
# 16823187
# found
# 16823186
# found
# 16823181
# found
# 16823179
# found
# 16823177
# found
# 16823175
# found
# 16823174
# found
# 16823171
# found
# 16823166
# found
# 16823164
# found
# 16823162
# found
# 16823161
# found
# 16823160
# found
# 16823159
# found
# 16823158
# found
# 16823157
# found
# 16823156
# found
# 16823155
# found
# 16823154
# found
# 16823153
# found
# 16823152
# found
# 16823151
# found
# 16823149
# found
# 16823148
# found
# 16823147
# found
# 16823146
# found
# 16823145
# found
# 16823144
# found
# 16823143
# found
# 16823142
# found
# 16823141
# found
# 16823139
# found
# 16823138
# found
# 16823137
# found
# 16823136
# found
# 16823134
# found
# 16823133
# found
# 16823132
# found
# 16823131
# found
# 16823130
# found
# 16823129
# found
# 16823128
# found
# 16823126
# found
# 16823125
# found
# 16823124
# found
# 16823123
# found
# 16823121
# found
# 16823119
# found
# 16823117
# found
# 16823116
# found
# 16823115
# found
# 16823114
# found
# 16823113
# found
# 16823112
# found
# 16823111
# found
# 16823110
# found
# 16823109
# found
# 16823108
# found
# 16823107
# found
# 16823106
# found
# 16823104
# found
# 16823103
# found
# 16823101
# found
# 16823100
# found
# 16823099
# found
# 16823098
# found
# 16823096
# found
# 16823095
# found
# 16823094
# found
# 16823093
# found
# 16823092
# found
# 16823091
# found
# 16823090
# found
# 16823089
# found
# 16823088
# found
# 16823087
# found
# 16823085
# found
# 16823084
# found
# 16823083
# found
# 16823081
# found
# 16823080
# found
# 16823074
# found
# 16823069
# found
# 16823067
# found
# 16823065
# found
# 16823063
# found
# 16823062
# found
# 16823060
# found
# 16823058
# found
# 16823057
# found
# 16823056
# found
# 16823055
# found
# 16823052
# found
# 16823051
# found
# 16823050
# found
# 16823048
# found
# 16823046
# found
# 16823045
# found
# 16823044
# found
# 16823042
# found
# 16823040
# found
# 16823039
# found
# 16823036
# found
# 16823035
# found
# 16823034
# found
# 16823032
# found
# 16823030
# found
# 16823028
# found
# 16823026
# found
# 16823024
# found
# 16823023
# found
# 16823015
# found
# 16823014
# found
# 16823009
# found
# 16823008
# found
# 16823003
# found
# 16823000

# %%
###специализации
import httplib
import json
headers = {"Authorization": "Bearer PHUAM0L3PU56VNT041CJM3MUTGSABUCDTMBVHEAMF5CGCDEEIC7VFFT4VLOP0GQP", 
           "User-Agent": "hh-recommender"}
conn = httplib.HTTPSConnection("api.hh.ru")
conn.request("GET", "/specializations", headers=headers)
r1 = conn.getresponse()

#print json.loads(r1.read())
specs = {}
for k in [d['specializations'] for d in json.loads(r1.read())]:
    for n in k:
        specs[n['id']] = n['name']
print specs
# Out:
# {u'7.14': u'\u0410\u0432\u0442\u043e\u0437\u0430\u043f\u0447\u0430\u0441\u0442\u0438', u'16.658': u'\u041c\u0443\u043d\u0438\u0446\u0438\u043f\u0430\u043b\u0438\u0442\u0435\u0442', u'21.292': u'\u0422\u0430\u043c\u043e\u0436\u0435\u043d\u043d\u043e\u0435 \u043e\u0444\u043e\u0440\u043c\u043b\u0435\u043d\u0438\u0435', u'23.362': u'\u042e\u0440\u0438\u0441\u043a\u043e\u043d\u0441\u0443\u043b\u044c\u0442', u'6.336': u'\u0423\u0447\u0435\u0442 \u043a\u0430\u0434\u0440\u043e\u0432', u'23.165': u'\u041d\u0430\u043b\u043e\u0433\u043e\u0432\u043e\u0435 \u043f\u0440\u0430\u0432\u043e', u'5.61': u'\u0414\u0435\u043d\u0435\u0436\u043d\u044b\u0439 \u0440\u044b\u043d\u043e\u043a (money market)', u'17.623': u'\u0424\u0438\u043d\u0430\u043d\u0441\u043e\u0432\u044b\u0435 \u0443\u0441\u043b\u0443\u0433\u0438', u'1.10': u'Web \u043c\u0430\u0441\u0442\u0435\u0440', u'3.166': u'\u041d\u0430\u0440\u0443\u0436\u043d\u0430\u044f \u0440\u0435\u043a\u043b\u0430\u043c\u0430', u'5.367': u'\u041c\u0435\u0442\u043e\u0434\u043e\u043b\u043e\u0433\u0438\u044f, \u0411\u0430\u043d\u043a\u043e\u0432\u0441\u043a\u0438\u0435 \u0442\u0435\u0445\u043d\u043e\u043b\u043e\u0433\u0438\u0438', u'5.366': u'\u0420\u0438\u0441\u043a\u0438: \u043f\u0440\u043e\u0447\u0438\u0435', u'5.365': u'\u041e\u0446\u0435\u043d\u043a\u0430 \u0437\u0430\u043b\u043e\u0433\u0430, \u0421\u0442\u043e\u0438\u043c\u043e\u0441\u0442\u0438 \u0438\u043c\u0443\u0449\u0435\u0441\u0442\u0432\u0430', u'5.369': u'\u041e\u0442\u0447\u0435\u0442\u043d\u043e\u0441\u0442\u044c', u'5.368': u'\u0420\u0430\u0437\u0440\u0430\u0431\u043e\u0442\u043a\u0430 \u043d\u043e\u0432\u044b\u0445 \u043f\u0440\u043e\u0434\u0443\u043a\u0442\u043e\u0432, \u041c\u0430\u0440\u043a\u0435\u0442\u0438\u043d\u0433', u'13.268': u'\u0421\u0435\u0440\u0442\u0438\u0444\u0438\u043a\u0430\u0446\u0438\u044f', u'22.518': u'\u0421\u043e\u043c\u0435\u043b\u044c\u0435', u'22.104': u'\u041a\u0435\u0439\u0442\u0435\u0440\u0438\u043d\u0433', u'29.560': u'\u042d\u043b\u0435\u043a\u0442\u0440\u043e\u043c\u043e\u043d\u0442\u0435\u0440, \u041a\u0430\u0431\u0435\u043b\u044c\u0449\u0438\u043a', u'29.561': u'\u042e\u0432\u0435\u043b\u0438\u0440', u'11.436': u'\u041a\u0438\u043d\u043e', u'18.57': u'\u0413\u043b\u0430\u0432\u043d\u044b\u0439 \u0438\u043d\u0436\u0435\u043d\u0435\u0440', u'18.56': u'\u0413\u043b\u0430\u0432\u043d\u044b\u0439 \u0430\u0433\u0440\u043e\u043d\u043e\u043c', u'22.193': u'\u041e\u0444\u0438\u0446\u0438\u0430\u043d\u0442, \u0411\u0430\u0440\u043c\u0435\u043d', u'18.174': u'\u041d\u0430\u0447\u0430\u043b\u044c\u043d\u044b\u0439 \u0443\u0440\u043e\u0432\u0435\u043d\u044c, \u041c\u0430\u043b\u043e \u043e\u043f\u044b\u0442\u0430', u'22.198': u'\u041e\u0440\u0433\u0430\u043d\u0438\u0437\u0430\u0446\u0438\u044f \u0432\u0441\u0442\u0440\u0435\u0447, \u041a\u043e\u043d\u0444\u0435\u0440\u0435\u043d\u0446\u0438\u0439', u'22.199': u'\u041e\u0440\u0433\u0430\u043d\u0438\u0437\u0430\u0446\u0438\u044f \u0442\u0443\u0440\u0438\u0441\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0445 \u043f\u0440\u043e\u0434\u0443\u043a\u0442\u043e\u0432', u'7.455': u'\u0428\u0438\u043d\u044b, \u0414\u0438\u0441\u043a\u0438', u'22.204': u'\u041f\u0435\u0440\u0441\u043e\u043d\u0430\u043b \u043a\u0443\u0445\u043d\u0438', u'15.308': u'\u0422\u0440\u0430\u043d\u0441\u043f\u043e\u0440\u0442, \u041b\u043e\u0433\u0438\u0441\u0442\u0438\u043a\u0430', u'14.60': u'\u0413\u0443\u043c\u0430\u043d\u0438\u0442\u0430\u0440\u043d\u044b\u0435 \u043d\u0430\u0443\u043a\u0438', u'24.493': u'\u041f\u0430\u0440\u0438\u043a\u043c\u0430\u0445\u0435\u0440', u'24.492': u'\u041c\u0430\u0441\u0441\u0430\u0436\u0438\u0441\u0442', u'9.22': u'\u0410\u0434\u043c\u0438\u043d\u0438\u0441\u0442\u0440\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u0435', u'19.421': u'\u0410\u043a\u0442\u0443\u0430\u0440\u0438\u0439', u'3.236': u'\u041f\u0440\u043e\u0438\u0437\u0432\u043e\u0434\u0441\u0442\u0432\u043e \u0440\u0435\u043a\u043b\u0430\u043c\u044b', u'3.230': u'\u041f\u0440\u043e\u0434\u0432\u0438\u0436\u043 ...
# 0.13013013013

# %%
###ЗП
real = 100000.0
expected = 100000.0
print 1-(abs(expected-real)/max(real,expected))
# Out:
# 100.3
# 1.0

# %%
##опыт работы
real = 0
expected = 0
print (3.0 - abs(real-expected))/3
# Out:
# 1.0

# %%
##навыки
import httplib
import json
import pickle
headers = {"Authorization": "Bearer UGE7369P4FJVPH027PQII1S422JHFJ2NQADKREFO8KTUP1BCIJQ2T6BUQ7CLQMGF", 
           "User-Agent": "hh-recommender"}
conn = httplib.HTTPSConnection("api.hh.ru")
conn.request("GET", "/specializations", headers=headers)
r1 = conn.getresponse()

# print json.loads(r1.read())
spec_ids = []
spec_names = []
for k in [d['specializations'] for d in json.loads(r1.read())]:
    for n in k:
        spec_ids.append(n['id'])
        spec_names.append(n['name'])
pickle.dump( spec_ids, open( "spec_ids.p", "wb" ) )
pickle.dump( spec_names, open( "spec_names.p", "wb" ) )

# %%
##вытаскиваем из вакансий ключевые навыки
import json
from tinydb import TinyDB
import pickle

db = TinyDB('/home/shurik2533/vacancies.json')
db2 = TinyDB('/home/shurik2533/vacancies2.json')
vacancies = db.all()
vacancies2 = db2.all()
all_key_skills = []
key_skills_set = set()
key_skills_dict = dict()
for vacancy in vacancies:
#     print vacancy['name']
    for skill in vacancy['key_skills']:
        all_key_skills.append(skill['name'])
        key_skills_set.add(skill['name'])
        if skill['name'] in key_skills_dict:
            key_skills_dict[skill['name']] = key_skills_dict[skill['name']]+1;
        else:
            key_skills_dict[skill['name']] = 1;
#     print vacancy['description']

for vacancy in vacancies2:
#     print vacancy['name']
    for skill in vacancy['key_skills']:
        all_key_skills.append(skill['name'])
        key_skills_set.add(skill['name'])
        if skill['name'] in key_skills_dict:
            key_skills_dict[skill['name']] = key_skills_dict[skill['name']]+1;
        else:
            key_skills_dict[skill['name']] = 1;
#     print vacancy['description']


print len(all_key_skills)
print len(key_skills_set)
for k in key_skills_dict.keys():
    if key_skills_dict[k] == 1:
        del key_skills_dict[k]

res = list(key_skills_dict.keys())
pickle.dump( res, open( "key_skills.p", "wb" ) )
# Out:
# 93088
# 7999

# %%
import pickle
key_skills = pickle.load( open( "key_skills.p", "rb" ) )
print len(key_skills)
# Out:
# 2574

# %%
import json
from tinydb import TinyDB
import pickle
import Stemmer
import re 

db = TinyDB('/home/shurik2533/vacancies.json')
db2 = TinyDB('/home/shurik2533/vacancies2.json')
vacancies1 = db.all()
vacancies2 = db2.all()
vacancies = vacancies1+vacancies2

titles_s = set()
for vac in vacancies:
    titles_s.add(vac['name'])
print len(titles_s)
title_words = dict()
stemmer = Stemmer.Stemmer('russian')
for title in titles_s:
    title = re.sub(ur'[^a-zа-я]+', ' ', title, re.UNICODE)
    words = re.split(r'\s{1,}', title.strip())
    for word in words:
        word = stemmer.stemWord(word.lower())
        if word in title_words:
            title_words[word] = title_words[word]+1;
        else:
            title_words[word] = 1;
print len(title_words)
for k in title_words.keys():
    if title_words[k] == 1 or len(k.strip()) <= 1:
        del title_words[k]
print len(title_words)
pickle.dump( title_words, open( "title_words.p", "wb" ) )
# vacancies.append(vacancies2)
# print len(vacancies)
# Out:
# 44308
# 11321
# 6157

# %%
import json
from tinydb import TinyDB
import pickle
import Stemmer
import re 

db = TinyDB('/home/shurik2533/vacancies.json')
db2 = TinyDB('/home/shurik2533/vacancies2.json')
vacancies1 = db.all()
vacancies2 = db2.all()
vacancies = vacancies1+vacancies2

docs = []
for vac in vacancies:
    docs.append(vac['description'])
print len(docs)
    
    
doc_words = dict()
stemmer = Stemmer.Stemmer('russian')
p_docs = []
for doc in docs:
    p_doc = ""
    doc = re.sub('<[^>]*>', '', doc.lower())
    doc = re.sub('&quot;', '', doc)
    doc = re.sub(ur'[^a-zа-я]+', ' ', doc, re.UNICODE)
    words = re.split(r'\s{1,}', doc.strip())
    for word in words:
        word = stemmer.stemWord(word)
        p_doc = p_doc + " " + word
        if word in doc_words:
            doc_words[word] = doc_words[word]+1;
        else:
            doc_words[word] = 1;
    p_docs.append(p_doc)
print len(doc_words)
for k in doc_words.keys():
    if doc_words[k] == 1 or len(k.strip()) <= 1:
        del doc_words[k]
print len(doc_words)
# pickle.dump( doc_words, open( "doc_words.p", "wb" ) )
pickle.dump( p_docs, open( "processed_docs.p", "wb" ) )
print p_docs[0]
print docs[0]
# Out:
# 113289
# 290361
# 137670
#  юрист ведущ по претензион исков и договорн работ в област аренд недвижим в тр комплекс новомосковск в город московск ул хабаров м саларьев в администрац всег комплекс занима аренд коммерческ нежил помещен офис и торгов площади. обязанности: переговор с арендаторами. договорн работа. претензион - исков работ (иски, претенз и т. д.) представительств в арбитражн суд и административн процессе. требования: высш юридическ образование. хорош знан договорн работ в област аренд !!! оп работ с арбитражн суд в област «аренд недвижимости» ! условия: . гр/р: 5/2 , с 9.00 ч. – 18.00 ч. з/плата: пок 55 000 руб. - 60 000 руб. ( на рук ), в зависим от ваш опыта! карьерн рост : начальник юридическ отдела, с з/п до 100 000 руб. оплат телефон . оформлен по тк рф социальн пакет по тк рф в ближайш 3 - 4 месяц будет сво столов – бесплатн обеды! проезд: м. саларьево, 420 автобус, (10-12 минут), , остановк по требован «гостиничн комплекс.
# <p>Юрист (ведущий) по претензионно - исковой и договорной работе в области «Аренда недвижимости» в ТР Комплекс «НовоМосковский», в город Московский, ул. Хабарова (м. Саларьево). В администрацию всего Комплекса, занимающейся арендой коммерческих, нежилых помещений – офисы и торговые площади. </p> <p><strong>Обязанности: </strong></p> <ul> <li>Переговоры с Арендаторами.</li> <li>Договорная работа.</li> <li>Претензионно - исковая работа (иски, претензии и т. д.)</li> <li>Представительство в Арбитражном суде и административном процессе. </li> </ul> <p> <strong>Требования: </strong></p> <ul> <li>Высшее Юридическое образование. </li> <li>Хорошее знание Договорной работы в области Аренды !!!</li> <li>Опыт работы с Арбитражном судом в области «Аренда недвижимости» !</li> </ul> <p><strong>Условия: </strong>.</p> <ul> <li>Гр/р: 5/2 , с 9.00 ч. – 18.00 ч.</li> <li>З/плата: пока 55 000 руб. - 60 000 руб. ( на руки ), в зависимости от Вашего опыта!</li> <li>Карьерный рост : начальник юридического отдела, с з/п до 100 000 руб.</li> <li>Оплата телефона .</li> <li>Оформление по ТК РФ</li> <li>Социальный пакет по ТК РФ</li> <li>В ближайшие 3 - 4 месяца будет своя столовая – бесплатные обеды!</li> </ul> Проезд: М. Саларьево, 420 автобус, (10-12 минут), , остановка по требованию «Гостиничный Комплекс&quot;.

# %%
import re 
doc = "<p>Юрист (ведущий) по претензионно - исковой и договорной работе в области «Аренда недвижимости» в ТР Комплекс «НовоМосковский», в город Московский, ул. Хабарова (м. Саларьево). В администрацию всего Комплекса, занимающейся арендой коммерческих, нежилых помещений – офисы и торговые площади. </p> <p><strong>Обязанности: </strong></p> <ul> <li>Переговоры с Арендаторами.</li> <li>Договорная работа.</li> <li>Претензионно - исковая работа (иски, претензии и т. д.)</li> <li>Представительство в Арбитражном суде и административном процессе. </li> </ul> <p> <strong>Требования: </strong></p> <ul> <li>Высшее Юридическое образование. </li> <li>Хорошее знание Договорной работы в области Аренды !!!</li> <li>Опыт работы с Арбитражном судом в области «Аренда недвижимости» !</li> </ul> <p><strong>Условия: </strong>.</p> <ul> <li>Гр/р: 5/2 , с 9.00 ч. – 18.00 ч.</li> <li>З/плата: пока 55 000 руб. - 60 000 руб. ( на руки ), в зависимости от Вашего опыта!</li> <li>Карьерный рост : начальник юридического отдела, с з/п до 100 000 руб.</li> <li>Оплата телефона .</li> <li>Оформление по ТК РФ</li> <li>Социальный пакет по ТК РФ</li> <li>В ближайшие 3 - 4 месяца будет своя столовая – бесплатные обеды!</li> </ul> Проезд: М. Саларьево, 420 автобус, (10-12 минут), , остановка по требованию «Гостиничный Комплекс&quot;."
doc = re.sub('<[^>]*>', '', doc)
print doc
# Out:
# Юрист (ведущий) по претензионно - исковой и договорной работе в области «Аренда недвижимости» в ТР Комплекс «НовоМосковский», в город Московский, ул. Хабарова (м. Саларьево). В администрацию всего Комплекса, занимающейся арендой коммерческих, нежилых помещений – офисы и торговые площади.  Обязанности:   Переговоры с Арендаторами. Договорная работа. Претензионно - исковая работа (иски, претензии и т. д.) Представительство в Арбитражном суде и административном процессе.    Требования:   Высшее Юридическое образование.  Хорошее знание Договорной работы в области Аренды !!! Опыт работы с Арбитражном судом в области «Аренда недвижимости» !  Условия: .  Гр/р: 5/2 , с 9.00 ч. – 18.00 ч. З/плата: пока 55 000 руб. - 60 000 руб. ( на руки ), в зависимости от Вашего опыта! Карьерный рост : начальник юридического отдела, с з/п до 100 000 руб. Оплата телефона . Оформление по ТК РФ Социальный пакет по ТК РФ В ближайшие 3 - 4 месяца будет своя столовая – бесплатные обеды!  Проезд: М. Саларьево, 420 автобус, (10-12 минут), , остановка по требованию «Гостиничный Комплекс&quot;.

# %%
import pickle
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import VarianceThreshold
from scipy import spatial
from sklearn.metrics.pairwise import cosine_similarity
import heapq
import numpy

doc_words = pickle.load( open( "processed_docs.p", "rb" ) )

vectorizer = CountVectorizer(min_df=1)
X = vectorizer.fit_transform(doc_words)
T = vectorizer.transform(['java разработчик программист'])

print X.shape

sel = VarianceThreshold(threshold=(.9999 * (1 - .9999)))
X2 = sel.fit_transform(X)
T2 = sel.transform(T)
print T2.toarray()

print X2.shape

transformer = TfidfTransformer()
X2_tfidf = transformer.fit_transform(X2)

T2_tfidf = transformer.transform(T2)
result = cosine_similarity(T2_tfidf, X2_tfidf)

res = heapq.nlargest(10, range(len(result[0])), result[0].take)
#print doc_words[result.argmax(axis=1)]
for i in res:
    print doc_words[i]
    
# i = 0
# for x_row in X2_tfidf:
#     result = cosine_similarity(T2_tfidf, x_row)
#     #result = spatial.distance.cosine(, )
#     print result
#     i = i+1
#     if i > 10:
#         break
#result = spatial.distance.cosine(T2_tfidf, X2_tfidf)
# Out:
# (113289, 120498)
# [[0 0 0 ..., 0 0 0]]
# (113289, 27624)
#  компан ведущ разработчик интегрирова банковск сист треб ведущ разработчик java обязан разработк приложен для крупн банк и государствен организац участ в research amp development проект связа с импортозамещен программн продукт разработк техническ требован к приложен совместн с заказчик и аналитиками. разработк архитектур приложений, проектирован компонентов. планирован работ групп разработчик java. разработк и постановк задан для разработчик на реализац отдельн компонент системы. контрол выполнен задач разработчиками. требования: образован высшее; оп разработк на java от 3 лет; желател оп руководств it-проект и групп разработчик java от 1 года; знан и оп работы: spring framework stack; jdbc/jta, hibernate, jms; знан web-технолог и архитектур web-приложен java, vaadin; знан web-сервисов, soap, rest. знан реляцион субд (oracle, postgress); оп проектирован бд, знан sql. условия: офис м. семёновская; социальн пакет; возможн профессиональн роста.
#  для работ в it департамент а казкоммерцбанк треб специалист на должност ведущ программист разработчик основн требован знан java оп работ с фреймворк wicket spring знан sql приветств оп работ с oracle pl sql) знан английск (чтен техническ документации) ответственность, исполнительн высш техническ образован
#  в международн it компан sitex треб программист c c php ios java о ваканс интересн проект работ в команд профессиональн развит гибк график полн ил частичн занят хорош знан c c php ios, java, оп работ с основн инструмент из java-сред (eclipse, swing), баз дан (oracle и/ ms-sql), знан английск язык явля преимуществом. высыла резюме, описан сво проект и пример кода. без пример код резюм не рассматриваются!
#  обязан разработк java приложен требован оп работ java разработчик от лет знан основн java библиотек оп работ с sql систем контрол верс git английск на уровн чтен техническ документац дополнительн плюс будет явля знан swing, maven, ant, jsf, javascript, jquery, способн к разработк многопоточн приложений. условия: постоянная, полн день, работ на территор работодател оформление, отпуск, больничн и пр. по тк профессиональн и карьерн рост (заработн плат на испытательн строк) оплат питания, чай, кофе.
#  в международн компан zed котор явля провайдер и агрегатор мобильн контент а такж разработчик информацион развлекательн абонентск сервис открыт ваканс java разработчик в департамент ит департамент ит компан zed tema осуществля полн цикл техническ реализац бизнес компании, ведет разработк и поддержк высоконагружен сервис и использ для эт современ технологии, программн обеспечен и оборудован промышлен класс от ведущ производител - oracle, hp, cisco. есл вы знаете, что так баз дан в десятк терабайт, есл представля себ как работа распределен транзакции, есл слов «оптимизация», «производительность» и «tps» для вас не пуст звук, то вам будет интересн работа с нами! есл вы профессиона в администрирован unix-систем, ил баз дан oracle, есл разрабатыва серверн приложен на javaee ил pl/sql, пользовательск и программн интерфейс на php ил python, есл разбира в мобильн технолог ил имеет оп бизнес-анализ и постановк задач в эт област - мы буд рад приня вас в наш коллектив. обязанности: разработк и поддержк высоконагружен программн обеспечен с использован язык программирован java и технолог на основ эт языка; документирован созда обеспечен в соответств с принят в компан шаблон и регламентами. требования: высш техническ образование; техническ английский; оп разработк на java от 2-х лет; знан ide для разработк на java; знан core java; знан java io, java collections; знан dom/sax api; знан jdbc, jms, ejb 3.x; оп работ с многопоточн приложениями; оп работ с сервер приложен tomcat/glassfish 3.x; оп работ с субд mysql, oracle; оп работ с svn/jira. условия: официальн оформление; офис в центре; социальн пакет; заработн плат обсужда с успешн кандидатами; постоя совершенствован подход к реализац сложн и интересн проектов; дружн и сплочен команд профессионал под начал сильн руководителя; внимательн отношен к инициатив и иде сотрудников.
#  программист php оп год ищ программист ов php он же веб разработчик он же программист разработчик он же php разработчик требован треб навык оп необходим для разработк сайт на php достаточн для самостоятельн работы. обязательн ярк выражен стремлен развива в дан направлен в долгосрочн перспектив (мин. 3-5 лет), повыша квалификацию, в т.ч. в личн время. условия: работа в основн с 1с-битрикс. поможем, подскажем, оплат профильн курсы. размер заработн плат при прием на работ и динамик дальн рост оплат в прям зависим от вклад сотрудник в работ коллектива. увеличен сложност проект и помощ в профессиональн рост гарантируем. реж работы: пн-пт, 8.30-17.00 в офис ест холодильник, микроволновка, чайник, ряд нескольк столовых. возьм перспективн стажера.
#  основн задач участ в проект в качеств разработчик оценк труд мкост доработок планирован срок реализац и срок включен доработок в релиз соблюден срок разработк подконтрольн направлен анализ и детальн проработк архитектур техническ экспертиза, макетирован (poc); написан техническ документации. требования: оп в качеств java-разработчик от 3 лет; оп построен enterprise приложений; оп работ в команд ~5 чел; высш техническ образование; технологии: spring, hibernate, extjs; язык программирован java ee, java script, pl sql; техническ английск (документация). условия: официальн оформлен согласн тк рф; бел заработн плат (оклад + бонусы) обсужда с успешн кандидатами; возможн обучен и сертификац за счет компании; крупн и уникальн проект в крупн развива компании.
#  есл вы java программист то мы приглаша вас в наш компан у нас интересн проект пол стартаперн у нас сам свеж стек технолог мы предлага вам присоедин к нам для реализац грандиозн проекта! ест ли у вас достаточн знан ил нет. мы рад провест интерв в люб случае!!! поспешите!!! ваканс открыт до 30-го апреля!!! обязанности: проектирован программн компонент платформ согласн требован разработк программн компонент платформ сопровождение, диагностик и устранен неисправн рабоч верс разрабатыва систем требования: знан принцип объектно-ориентирова программирован оп работ в качеств java разработчик (java, j2ee, java-based frameworks, spring framework) язык программирования: java 1.7, 1.8 необходим знан и оп работы: hibernate ил jpa ejb, cdi spring framework servlet/jsp jsf 2.0 primefaces, icefaces, richfaces xml javascript html css bootstrap есл знает ещё что-то, то эт плюс сервер приложений: jboss ил люб ин субд: postgresql, mysql ил друг условия: должностн оклад устанавлива по итог собеседован в соответств с профессиональн и личностн характеристик соискател и принят в компан систем оплат труд стабильн заработн плата, социальн и пенсион отчисления, оформлен на работ согласн трудов кодекс рк высок уровен корпоративн культуры, профессиональный, дружный, и доброжелательн коллект возможн карьерн рост как «горизонтального», так и «вертикального» возможн реализова сво способн в масштабн и интересн проект 5 дневн рабоч неделя, 8 часов рабоч ден поощрен трудолюб и активн испытательн срок – до 3-х месяц
#  обязан разработк приложен различн сложност для jvm на язык java разработк и доработк web приложен с использован web фреймворк play java совместн работ в существ команд разработчик требован налич высш образован окончен либ обучен на последн курсе) хорош знан java (j2ee, j2se), sql, html, javascript пониман ооп знан инфраструктур os linux желательно: владет английск язык на уровне, достаточн для изучен документац умет нестандартн мысл имет творческ подход к решен задач и трудолюб
#  обязан нескольк проект нуж универса либ знан java android либ java scala spark и т д требован хорош знан java full stack developer желательн знан web framework котор работа через json как сервер, например angular, zkoss условия: услов гибк - возможн частичн занят

# %%
import httplib
import json
import datetime
import MySQLdb
import ConfigParser
import time
import threading
from dateutil.parser import parse

current_time = lambda: int(round(time.time()))
start = current_time()
    
headers = {"User-Agent": "hh-recommender"}

config = ConfigParser.ConfigParser()
config.readfp(open('my.cfg'))

db = MySQLdb.connect(host="127.0.0.1", 
                     port=config.getint('mysqld', 'port'), 
                     user=config.get('mysqld', 'user'), 
                     passwd=config.get('mysqld', 'password'), 
                     db=config.get('mysqld', 'database') )
db.set_character_set('utf8')
cursor = db.cursor()
cursor.execute('SET NAMES utf8;')
cursor.execute('SET CHARACTER SET utf8;')
cursor.execute('SET character_set_connection=utf8;')
cursor.close()

def get_vacancy_ids():
    vacancy_ids = []
    conn = httplib.HTTPSConnection("api.hh.ru")
    per_page = 200
    page = 0
    count = per_page
    date_from = (datetime.datetime.now() - datetime.timedelta(minutes=5)).strftime('%Y-%m-%dT%H:%M:%S')
    date_to = datetime.datetime.now().strftime('%Y-%m-%dT%H:%M:%S')
    while count == per_page:
        path = ("/vacancies?per_page={}&date_from={}&date_to={}&page={}"
                .format(per_page, date_from, date_to, page))
        print path

        conn.request("GET", path, headers=headers)
        r1 = conn.getresponse()
        vacancies = r1.read()

        count = len(json.loads(vacancies)['items'])
        page = page+1
        for item in json.loads(vacancies)['items']:
            vacancy_ids.append(item['id'])
    return vacancy_ids
        

def process_vacancies(vacancy_ids):
    headers = {"User-Agent": "hh-recommender"}

    config = ConfigParser.ConfigParser()
    config.readfp(open('my.cfg'))

    db = MySQLdb.connect(host="127.0.0.1", 
                         port=config.getint('mysqld', 'port'), 
                         user=config.get('mysqld', 'user'), 
                         passwd=config.get('mysqld', 'password'), 
                         db=config.get('mysqld', 'database') )
    db.set_character_set('utf8')
    cursor = db.cursor()
    cursor.execute('SET NAMES utf8;')
    cursor.execute('SET CHARACTER SET utf8;')
    cursor.execute('SET character_set_connection=utf8;')
    cursor.close()

    for vac_id in vacancy_ids:
        conn = httplib.HTTPSConnection("api.hh.ru")
        conn.request("GET", "/vacancies/{}".format(vac_id), headers=headers)
        r1 = conn.getresponse()
        vacancy = r1.read()
        vacancy_json = json.loads(vacancy)
        cursor = db.cursor()
        cursor.execute("""
          INSERT INTO vacancies (id, updated, item) 
          VALUES (%s, %s, %s)
          ON DUPLICATE KEY UPDATE 
            updated  = VALUES(updated), 
            item   = VALUES(item)""", (vac_id, 
                                       parse(vacancy_json['published_at']).strftime("%Y-%m-%d %H:%M:%S"), 
                                       vacancy))
        db.commit() 
        cursor.close()
    db.close()

ids = get_vacancy_ids()
print len(ids)
vac_id_chunks=[ids[x:x+100] for x in xrange(0, len(ids), 100)]
t_num = 1;
threads = []
for vac_id_chunk in vac_id_chunks:
    print 'starting t{}'.format(t_num)
    t_num = t_num + 1
    t = threading.Thread(target=process_vacancies, kwargs={'vacancy_ids': vac_id_chunk})
    threads.append(t)
    t.start()
    
for t in threads:
    t.join()
    

db.close()
print "{} sec".format(current_time()-start)
# Out:
# /vacancies?per_page=200&date_from=2016-05-21T13:09:46&date_to=2016-05-21T13:14:46&page=0
# 39
# starting t1
# 21 sec

# %%
#vectorizer
import pickle
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import VarianceThreshold
from scipy import spatial
from sklearn.metrics.pairwise import cosine_similarity
import heapq
import numpy
from tinydb import TinyDB
import ConfigParser
import MySQLdb
import json

config = ConfigParser.ConfigParser()
config.readfp(open('my.cfg'))
db = MySQLdb.connect(host="127.0.0.1", 
                     port=config.getint('mysqld', 'port'), 
                     user=config.get('mysqld', 'user'), 
                     passwd=config.get('mysqld', 'password'), 
                     db=config.get('mysqld', 'database') )
db.set_character_set('utf8')
cursor = db.cursor()
cursor.execute('SET NAMES utf8;')
cursor.execute('SET CHARACTER SET utf8;')
cursor.execute('SET character_set_connection=utf8;')
cursor = db.cursor()
cursor.execute("""SELECT item FROM vacancies WHERE updated >= (NOW() - INTERVAL 7 DAY) LIMIT 10""")

spec_ids = pickle.load( open( "spec_ids.p", "rb" ) )
features = []

for item in cursor:
    print item[0]
    print '...................................'
    print json.loads(item[0])['specializations']
    print '-----------------------------------'
    
    
# #     specializations
#     vac_specializations = vacancy['specializations']
#     spec_features = [0] * len(spec_ids)
#     for vac_spec in vac_specializations:
#         spec_features[spec_ids.index(vac_spec['id'])] = 1
#     feature = feature + spec_features
    
#     features.append(feature)

cursor.close()

db.close()
    
print features

# db = TinyDB('vacancies.json')
# db2 = TinyDB('vacancies2.json')
# vacancies1 = db.all()
# vacancies2 = db2.all()
# vacancies = vacancies1+vacancies2

# spec_ids = pickle.load( open( "spec_ids.p", "rb" ) )

# # специацизации | уровни зп| тип занятости (0/1) | полнова раб дня (0/1) | опыт работы | навыки (собираем из вакансий) | 
# # список слов заголовка (собираем из вакансий) | текст (собираем из вакансий)
# features = []
# i = 0
# for vacancy in vacancies:
#     feature = []
    
#     #specializations
#     vac_specializations = vacancy['specializations']
#     spec_features = [0] * len(spec_ids)
#     for vac_spec in vac_specializations:
#         spec_features[spec_ids.index(vac_spec['id'])] = 1
#     feature = feature + spec_features
    
#     features.append(feature)
        
#     i = i+1;
#     if i > 10:
#         break;


# print len(features)
# print len(features[0])
# Out:
# {"alternate_url": "https://hh.ru/vacancy/16472332", "code": null, "premium": false, "description": "<strong>Обязанности:</strong> <ul> <li>Разработка объемно-планировочных решений</li> <li>Самостоятельное выполнение предпроектной, проектной и рабочей документации.</li> <li>Участие в подготовке архитектурно-планировочных и технических заданий.</li> <li>Взаимодействие со смежными инженерными разделами.</li> <li>Прохождение экспертизы.</li> <li>Ведение авторского надзора.</li> </ul> <strong>Требования:</strong> <ul> <li>Высшее архитектурное образование</li> <li>Хорошее знание нормативной базы.</li> <li>Опыт проектирования объектов</li> <li>Хорошее владение AutoCAD, ArchiCAD, 3D MAX</li> <li>Самостоятельный опыт проектирования зданий и сооружений.</li> </ul> <strong>Условия:</strong> <ul> <li>График работы: понедельник-пятница 9.00-18.00.</li> <li>Оклад по результату собеседования.</li> <li>Оформление в соответствии с ТК РФ.</li> <li>Работа в дружном коллективе.</li> <li>Готовность к командировкам.</li> </ul>", "schedule": {"id": "fullDay", "name": "Полный день"}, "suitable_resumes_url": null, "site": {"id": "hh", "name": "hh.ru"}, "billing_type": {"id": "standard", "name": "Стандарт"}, "published_at": "2016-05-19T14:15:54+0300", "test": null, "accept_handicapped": false, "experience": {"id": "between3And6", "name": "От 3 до 6 лет"}, "address": {"building": "16", "city": "Сочи", "description": null, "metro": null, "metro_stations": [], "raw": null, "street": "микрорайон Центральный, Нагорная улица", "lat": 43.577943, "lng": 39.7305}, "key_skills": [], "allow_messages": true, "employment": {"id": "full", "name": "Полная занятость"}, "id": "16472332", "response_url": null, "salary": {"to": null, "from": 40000, "currency": "RUR"}, "archived": false, "name": "Архитектор", "contacts": null, "created_at": "2016-05-19T14:15:54+0300", "area": {"url": "https://api.hh.ru/areas/237", "id": "237", "name": "Сочи"}, "relations": [], "employer": {"logo_urls": null, "vacancies_url": "https://api.hh.ru/vacancies?employer_id=1734990", "name": "ОСТ ГРУПП", "url": "https://api.hh.ru/employers/1734990", "alternate_url": "https://hh.ru/employer/1734990", "id": "1734990", "trusted": true}, "response_letter_required": false, "apply_alternate_url": "https://hh.ru/applicant/vacancy_response?vacancyId=16472332", "negotiations_url": null, "department": null, "branded_description": null, "hidden": false, "type": {"id": "open", "name": "Открытая"}, "specializations": [{"profarea_id": "20", "profarea_name": "Строительство, недвижимость", "id": "20.189", "name": "Нежилые помещения"}, {"profarea_id": "20", "profarea_name": "Строительство, недвижимость", "id": "20.63", "name": "Дизайн/Оформление"}, {"profarea_id": "20", "profarea_name": "Строительство, недвижимость", "id": "20.287", "name": "Строительство"}, {"profarea_id": "20", "profarea_name": "Строительство, недвижимость", "id": "20.233", "name": "Проектирование, Архитектура"}, {"profarea_id": "20", "profarea_name": "Строительство, недвижимость", "id": "20.58", "name": "Гостиницы, Магазины"}]}
# ...................................
# [{u'profarea_name': u'\u0421\u0442\u0440\u043e\u0438\u0442\u0435\u043b\u044c\u0441\u0442\u0432\u043e, \u043d\u0435\u0434\u0432\u0438\u0436\u0438\u043c\u043e\u0441\u0442\u044c', u'profarea_id': u'20', u'name': u'\u041d\u0435\u0436\u0438\u043b\u044b\u0435 \u043f\u043e\u043c\u0435\u0449\u0435\u043d\u0438\u044f', u'id': u'20.189'}, {u'profarea_name': u'\u0421\u0442\u0440\u043e\u0438\u0442\u0435\u043b\u044c\u0441\u0442\u0432\u043e, \u043d\u0435\u0434\u0432\u0438\u0436\u0438\u043c\u043e\u0441\u0442\u044c', u'profarea_id': u'20', u'name': u'\u0414\u0438\u0437\u0430\u0439\u043d/\u041e\u0444\u043e\u0440\u043c\u043b\u0435\u043d\u0438\u0435', u'id': u'20.63'}, {u'profarea_name': u'\u0421\u0442\u0440\u043e\u0438\u0442\u0435\u043b\u044c\u0441\u0442\u0432\u043e, \u043d\u0435\u0434\u0432\u0438\u0436\u0438\u043c\u043e\u0441\u0442\u044c', u'profarea_id': u'20', u'name': u'\u0421\u0442\u0440\u043e\u0438\u0442\u0435\u043b\u044c\u0441\u0442\u0432\u043e', u'id': u'20.287'}, {u'profarea_name': u'\u0421\u0442\u0440\u043e\u0438\u0442\u0435\u043b\u044c\u0441\u0442\u0432\u043e, \u043d\u0435\u0434\u0432\u0438\u0436\u0438\u043c\u043e\u0441\u0442\u044c', u'profarea_id': u'20', u'name': u'\u041f\u0440\u043e\u0435\u043a\u0442\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u0435, \u0410\u0440\u0445\u0438\u0442\u0435\u043a\u0442\u0443\u0440\u0430', u'id': u'20.233'}, {u'profarea_name': u'\u0421\u0442\u0440\u043e\u0438\u0442\u0435\u043b\u044c\u0441\u0442\u0432\u043e, \u043d\u0435\u0434\u0432\u0438\u0436\u0438\u043c\u043e\u0441\u0442\u044c', u'profarea_id': u'20', u'name': u'\u0413\u043e\u0441\u0442\u0438\u043d\u0438\u0446\u044b, \u041c\u0430\u0433\u0430\u0437\u0438\u043d\u044b', u'id': u'20.58'}]
# -----------------------------------
# {"alternate_url": "https://hh.ru/vacancy/16414913", "code": null, "premium": false, "description": "<p><strong>Сеть гипермаркетов &quot;ЛЕНТА&quot;, одна из крупнейших федеральных розничных сетей России, приглашает в свою команду Заместителя начальника мясного производства гипермаркета.</strong><strong> </strong></p> <p> </p> <p>Если Вы готовы организовать работу Мясного производства, имеете опыт руководства коллективом от 10 человек, то мы рады Вас видеть на должности <strong>Заместителя н</strong><strong>ачальника мясного производства гипермаркета «Лента»</strong>!</p> <p> </p> <p><strong>Обязанности: </strong></p> <ul> <li>организация ежедневной работы персонала, составление графиков выхода на работу;</li> <li>планирование выпуска готовой продукции и контроль выполнения сменных заданий по цехам;</li> <li>эффективное использование производственных мощностей;</li> <li>обучение и стажировка персонала;</li> <li>контроль соблюдения персоналом технологических процессов согласно нормативно-технической документации;</li> <li>контроль качества выпускаемой продукции;</li> <li>контроль выполнения санитарных норм и правил;</li> <li>взаимодействие с контролирующими, инспектирующими органами.</li> </ul> <p> </p> <p><strong>Требования: </strong></p> <ul> <li>высшее или среднее профессиональное образование;</li> <li>знание технологии производства продуктов питания;</li> <li>знание нормативно-правовой документации в области пищевого производства;</li> <li>опыт руководящей работы на предприятиях мясопереработки;</li> <li>уверенное владение ПК.</li> </ul> <p> </p> <p><strong>Успешному кандидату компания предлагает</strong>:</p> <ul> <li>достойный уровень вознаграждения;</li> <li>премирование по результатам работы;</li> <li>надбавку за выслугу лет;</li> <li>полный спектр социальных льгот;</li> <li>компенсационный пакет (льготное питание, добровольное медицинское страхование);</li> <li>внутрикорпоративное обучение и развитие;</li> <li>перспективу профессионального и карьерного роста;</li> <li>стабильную работу в дружной команде профессионалов.</li> </ul> <p><strong>Присоединяйтесь к нам! СДЕЛАЙТЕ карьеру в сильной Компании!</strong></p>", "schedule": {"id": "shift", "name": "Сменный график"}, "suitable_resumes_url": null, "site": {"id": "hh", "name": "hh.ru"}, "billing_type": {"id": "standard", "name": "Стандарт"}, "published_at": "2016-05-19T14:15:55+0300", "test": null, "accept_handicapped": false, "experience": {"id": "between1And3", "name": "От 1 года до 3 лет"}, "address": null, "key_skills": [], "allow_messages": true, "employment": {"id": "full", "name": "Полная занятость"}, "id": "16414913", "response_url": null, "salary": null, "archived": false, "name": "Заместитель начальника Мясного производства", "contacts": null, "created_at": "2016-05-19T14:15:55+0300", "area": {"url": "https://api.hh.ru/areas/4", "id": "4", "name": "Новосибирск"}, "relations": [], "employer": {"logo_urls": {"90": "https://hhcdn.ru/employer-logo/651083.png", "240": "https://hhcdn.ru/employer-logo/651084.png", "original": "https://hhcdn.ru/employer-logo-original/230620.png"}, "vacancies_url": "https://api.hh.ru/vacancies?employer_id=7172", "name": "Лента, федеральная розничная сеть", "url": "https://api.hh.ru/employers/7172", "alternate_url": "https://hh.ru/employer/7172", "id": "7172", "trusted": true}, "response_letter_required": false, "apply_alternate_url": "https://hh.ru/applicant/vacancy_response?vacancyId=16414913", "negotiations_url": null, "department": {"id": "7172-7172-gipe", "name": "Лента, федеральная розничная сеть, Гипермаркет"}, "branded_description": null, "hidden": false, "type": {"id": "open", "name": "Открытая"}, "specializations": [{"profarea_id": "18", "profarea_name": "Производство", "id": "18.208", "name": "Пищевая промышленность"}, {"profarea_id": "18", "profarea_name": "Производство", "id": "18.298", "name": "Технолог, Мясо- и птицепереработка"}, {"profarea_id": "17", "profarea_name": "Продажи", "id": "17.256", "name": "Розничная торговля ...
# ...................................
# [{u'profarea_name': u'\u041f\u0440\u043e\u0438\u0437\u0432\u043e\u0434\u0441\u0442\u0432\u043e', u'profarea_id': u'18', u'name': u'\u041f\u0438\u0449\u0435\u0432\u0430\u044f \u043f\u0440\u043e\u043c\u044b\u0448\u043b\u0435\u043d\u043d\u043e\u0441\u0442\u044c', u'id': u'18.208'}, {u'profarea_name': u'\u041f\u0440\u043e\u0438\u0437\u0432\u043e\u0434\u0441\u0442\u0432\u043e', u'profarea_id': u'18', u'name': u'\u0422\u0435\u0445\u043d\u043e\u043b\u043e\u0433, \u041c\u044f\u0441\u043e- \u0438 \u043f\u0442\u0438\u0446\u0435\u043f\u0435\u0440\u0435\u0440\u0430\u0431\u043e\u0442\u043a\u0430', u'id': u'18.298'}, {u'profarea_name': u'\u041f\u0440\u043e\u0434\u0430\u0436\u0438', u'profarea_id': u'17', u'name': u'\u0420\u043e\u0437\u043d\u0438\u0447\u043d\u0430\u044f \u0442\u043e\u0440\u0433\u043e\u0432\u043b\u044f', u'id': u'17.256'}, {u'profarea_name': u'\u041f\u0440\u043e\u0434\u0430\u0436\u0438', u'profarea_id': u'17', u'name': u'\u0422\u043e\u0440\u0433\u043e\u0432\u044b\u0435 \u0441\u0435\u0442\u0438', u'id': u'17.535'}, {u'profarea_name': u'\u0422\u0443\u0440\u0438\u0437\u043c, \u0433\u043e\u0441\u0442\u0438\u043d\u0438\u0446\u044b, \u0440\u0435\u0441\u0442\u043e\u0440\u0430\u043d\u044b', u'profarea_id': u'22', u'name': u'\u0428\u0435\u0444-\u043f\u043e\u0432\u0430\u0440', u'id': u'22.353'}, {u'profarea_name': u'\u0422\u0443\u0440\u0438\u0437\u043c, \u0433\u043e\u0441\u0442\u0438\u043d\u0438\u0446\u044b, \u0440\u0435\u0441\u0442\u043e\u0440\u0430\u043d\u044b', u'profarea_id': u'22', u'name': u'\u0423\u043f\u0440\u0430\u0432\u043b\u0435\u043d\u0438\u0435 \u0440\u0435\u0441\u0442\u043e\u0440\u0430\u043d\u0430\u043c\u0438, \u0411\u0430\u0440\u0430\u043c\u0438', u'id': u'22.329'}]
# -----------------------------------
# {"alternate_url": "https://hh.ru/vacancy/13782334", "code": null, "premium": false, "description": "<p>Удаленный оператор</p> <p><strong>Обязанности:</strong></p> <ul> <li>Активные продажи по телефону - совершение звонков потенциальным клиентам с предложением оформить заявку на кредитную карту Банка Тинькофф;</li> <li>Внесение предоставленных потенциальным клиентом данных в анкету на сайте Банка Тинькофф;</li> <li>Консультирование потенциальных клиентов по услугам и продуктам Банка Тинькофф;</li> <li>Обработка заявок по информационной базе, предоставленной Банком Тинькофф (поиск клиентов не требуется);</li> <li>Выполнение плана по продажам.</li> </ul> <p><strong>Требования:</strong></p> <ul> <li>Наличие СНИЛС;</li> <li>Наличие компьютера, проводного (выделенного) интернета и головной гарнитуры (наушники с микрофоном);</li> <li>Обеспечение тишины во время разговора;</li> <li>Активная жизненная позиция, желание работать и зарабатывать в сфере продаж;</li> <li>Коммуникабельность, готовность работать с возражениями;</li> <li>Возможность приступить к обработке заявок в течение ближайших 2-х недель.</li> </ul> <p><strong>Условия:</strong></p> <ul> <li>Обработка заявок из дома в комфортных для вас условиях;</li> <li>Даты выполнения работ устанавливаются совместно с Банком, время - вы выбираете самостоятельно;</li> <li>Вознаграждение зависит от количества продаж и качества консультаций;</li> <li>Среднемесячное вознаграждение на начальных этапах, при условии, что оператор уделяет обработке заявок не менее 40 часов в неделю, составляет около 20 000 рублей;</li> <li>Ежемесячные бонусы в зависимости от результатов;</li> <li>Оформление по гражданско-правовому договору, предусматривающий страховые отчисления в Пенсионный фонд РФ, а также удержание НДФЛ и перечисление в Бюджетную систему РФ;</li> <li>Бесплатное обучение технике продаж (вебинары, тренинги, конференции);</li> <li>Предоставляемая и оплачиваемая Банком телефония;</li> <li>Основное количество заявок для обработки выпадает с 10 до 21 часов по московскому времени, в остальные часы наличие заявок не гарантируется.</li> </ul> <p>В случае заинтересованности со стороны Банка, на адрес электронной почты Вам поступит письмо с подробными условиями присоединения к проекту Домашний колл-центр.</p>", "schedule": {"id": "remote", "name": "Удаленная работа"}, "suitable_resumes_url": null, "site": {"id": "hh", "name": "hh.ru"}, "billing_type": {"id": "standard", "name": "Стандарт"}, "published_at": "2016-05-19T14:15:59+0300", "test": null, "accept_handicapped": true, "experience": {"id": "noExperience", "name": "Нет опыта"}, "address": null, "key_skills": [], "allow_messages": false, "employment": {"id": "part", "name": "Частичная занятость"}, "id": "13782334", "response_url": null, "salary": null, "archived": false, "name": "Оператор", "contacts": null, "created_at": "2016-05-19T14:15:59+0300", "area": {"url": "https://api.hh.ru/areas/1309", "id": "1309", "name": "Далматово"}, "relations": [], "employer": {"logo_urls": {"90": "https://hhcdn.ru/employer-logo/1429665.png", "original": "https://hhcdn.ru/employer-logo-original/246748.png", "240": "https://hhcdn.ru/employer-logo/1429666.png"}, "vacancies_url": "https://api.hh.ru/vacancies?employer_id=78638", "name": "Тинькофф Банк", "url": "https://api.hh.ru/employers/78638", "alternate_url": "https://hh.ru/employer/78638", "id": "78638", "trusted": true}, "response_letter_required": false, "apply_alternate_url": "https://hh.ru/applicant/vacancy_response?vacancyId=13782334", "negotiations_url": null, "department": null, "branded_description": "\n<style>\n.tmpl_hh-wrapper h1,\n.tmpl_hh-wrapper h2,\n.tmpl_hh-wrapper h3,\n.tmpl_hh-wrapper h4,\n.tmpl_hh-wrapper h5,\n.tmpl_hh-wrapper h6,\n.tmpl_hh-wrapper p,\n.tmpl_hh-wrapper blockquote,\n.tmpl_hh-wrapper pre,\n.tmpl_hh-wrapper a,\n.tmpl_hh-wrapper abbr,\n.tmpl_hh-wrapper acronym,\n.tmpl_hh-wrapper address,\n.tmpl_hh-wrapper big,\n.tmpl_hh-wrapper cite,\n.tmpl_hh-wrapper code,\n.tmpl_hh-wrapper img,\n.t ...
# ...................................
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-4a8759b8d90b> in <module>()
#      35     print item[0]
#      36     print '...................................'
# ---> 37     print json.loads(item[0])['specializations']
#      38     print '-----------------------------------'
#      39
#
# /home/shurik2533/anaconda/lib/python2.7/json/__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337             parse_int is None and parse_float is None and
#     338             parse_constant is None and object_pairs_hook is None and not kw):
# --> 339         return _default_decoder.decode(s)
#     340     if cls is None:
#     341         cls = JSONDecoder
#
# /home/shurik2533/anaconda/lib/python2.7/json/decoder.pyc in decode(self, s, _w)
#     362
#     363         """
# --> 364         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     365         end = _w(s, end).end()
#     366         if end != len(s):
#
# /home/shurik2533/anaconda/lib/python2.7/json/decoder.pyc in raw_decode(self, s, idx)
#     378         """
#     379         try:
# --> 380             obj, end = self.scan_once(s, idx)
#     381         except StopIteration:
#     382             raise ValueError("No JSON object could be decoded")
#
# ValueError: Unterminated string starting at: line 1 column 5243 (char 5242)
